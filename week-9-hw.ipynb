# %%
import pandas as pd

# %%
nyaccidents=pd.read_csv("data/accidents-nyc.csv")

# %%
nyaccidents
# Out:
#        CRASH DATE CRASH TIME        BOROUGH  NUMBER OF PERSONS INJURED  \
# 0         4/13/21      21:35       BROOKLYN                          1
# 1         4/13/21      16:00       BROOKLYN                          0
# 2         4/13/21      17:30         QUEENS                          0
# 3         4/11/21      21:06       BROOKLYN                          1
# 4         4/15/21      20:00  STATEN ISLAND                          0
# ...           ...        ...            ...                        ...
# 282868     1/1/19      19:00       BROOKLYN                          0
# 282869     1/1/19       8:00          BRONX                          0
# 282870     1/1/19       3:30          BRONX                          0
# 282871     1/1/19      19:30       BROOKLYN                          0
# 282872     1/1/19      12:00      MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# ...

# %%
nyaccidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282873 entries, 0 to 282872
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH DATE                     282873 non-null  object
#  1   CRASH TIME                     282873 non-null  object
#  2   BOROUGH                        282873 non-null  object
#  3   NUMBER OF PERSONS INJURED      282873 non-null  int64
#  4   NUMBER OF PERSONS KILLED       282873 non-null  int64
#  5   NUMBER OF PEDESTRIANS INJURED  282873 non-null  int64
#  6   NUMBER OF PEDESTRIANS KILLED   282873 non-null  int64
#  7   NUMBER OF CYCLIST INJURED      282873 non-null  int64
#  8   NUMBER OF CYCLIST KILLED       282873 non-null  int64
#  9   NUMBER OF MOTORIST INJURED     282873 non-null  int64
#  10  NUMBER OF MOTORIST KILLED      282873 non-null  int64
#  11  CONTRIBUTING FACTOR VEHICLE 1  281489 non-null  object
# ...

# %%
nyaccidents["CRASH DATE"]
# Out:
# 0         4/13/21
# 1         4/13/21
# 2         4/13/21
# 3         4/11/21
# 4         4/15/21
#            ...
# 282868     1/1/19
# 282869     1/1/19
# 282870     1/1/19
# 282871     1/1/19
# 282872     1/1/19
# Name: CRASH DATE, Length: 282873, dtype: object

# %%
#which borough has the most crashes
nyaccidents["BOROUGH"]
# Out:
# 0              BROOKLYN
# 1              BROOKLYN
# 2                QUEENS
# 3              BROOKLYN
# 4         STATEN ISLAND
#               ...
# 282868         BROOKLYN
# 282869            BRONX
# 282870            BRONX
# 282871         BROOKLYN
# 282872        MANHATTAN
# Name: BOROUGH, Length: 282873, dtype: object

# %%
borough_sort = nyaccidents.sort_values(by=["BOROUGH"],ascending=False)

# %%
borough_sort
# Out:
#        CRASH DATE CRASH TIME        BOROUGH  NUMBER OF PERSONS INJURED  \
# 232746    5/18/19      21:46  STATEN ISLAND                          1
# 208313     7/8/19      12:00  STATEN ISLAND                          1
# 43604     11/8/20       6:40  STATEN ISLAND                          1
# 208334    6/30/19      16:20  STATEN ISLAND                          0
# 114549    3/14/20      13:15  STATEN ISLAND                          0
# ...           ...        ...            ...                        ...
# 66936      9/1/20      14:05          BRONX                          0
# 66935     8/23/20      16:03          BRONX                          1
# 239428    4/17/19      10:46          BRONX                          0
# 239429    4/17/19      18:04          BRONX                          1
# 173234   10/18/19       9:21          BRONX                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# ...

# %%
df_brooklyn=nyaccidents[nyaccidents["BOROUGH"]== "BROOKLYN"]

# %%
df_brooklyn
# Out:
#        CRASH DATE CRASH TIME   BOROUGH  NUMBER OF PERSONS INJURED  \
# 0         4/13/21      21:35  BROOKLYN                          1
# 1         4/13/21      16:00  BROOKLYN                          0
# 3         4/11/21      21:06  BROOKLYN                          1
# 5         5/21/19      22:50  BROOKLYN                          0
# 7         3/31/21      22:20  BROOKLYN                          1
# ...           ...        ...       ...                        ...
# 282857     1/1/19       0:19  BROOKLYN                          1
# 282859     1/1/19       6:51  BROOKLYN                          1
# 282865     1/1/19       9:05  BROOKLYN                          0
# 282868     1/1/19      19:00  BROOKLYN                          0
# 282871     1/1/19      19:30  BROOKLYN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 0                              0                              1
# ...

# %%
nyaccidents["BOROUGH"].value_counts()
#BROOKLYN HAD THE MOST ACCIDENTS
# Out:
# BROOKLYN         95099
# QUEENS           80085
# BRONX            50123
# MANHATTAN        48864
# STATEN ISLAND     8702
# Name: BOROUGH, dtype: int64

# %%
#primary vehicle involved - is SEDANS

# %%
nyaccidents["VEHICLE TYPE CODE 1"].value_counts()
# Out:
# Sedan                                  129987
# Station Wagon/Sport Utility Vehicle    102850
# Taxi                                    10647
# Pick-up Truck                            7183
# Box Truck                                5504
#                                         ...
# SLINGSHOT                                   1
# CHEVY EXPR                                  1
# Go kart                                     1
# FDNY Engin                                  1
# MAC T                                       1
# Name: VEHICLE TYPE CODE 1, Length: 633, dtype: int64

# %%
nyaccidents["VEHICLE TYPE CODE 2"].value_counts()
# Out:
# Sedan                                  84241
# Station Wagon/Sport Utility Vehicle    68723
# Bike                                    8544
# Taxi                                    6939
# Box Truck                               6365
#                                        ...
# e-bike                                     1
# FRIEGHTLIN                                 1
# ESCOOTER                                   1
# Electric s                                 1
# G COM                                      1
# Name: VEHICLE TYPE CODE 2, Length: 735, dtype: int64

# %%
v1 = nyaccidents["VEHICLE TYPE CODE 1"]

# %%
v2 = nyaccidents["VEHICLE TYPE CODE 2"]

# %%
all_v = v1+v2

# %%
#5 unusual vehicles are e-bikes, go carts, Slingshot, Chevy Expr, MacT, Frightelin

# %%
all_v.value_counts(ascending=False)
# Out:
# SedanSedan                                                                41834
# Station Wagon/Sport Utility VehicleStation Wagon/Sport Utility Vehicle    29523
# SedanStation Wagon/Sport Utility Vehicle                                  28438
# Station Wagon/Sport Utility VehicleSedan                                  27829
# SedanBike                                                                  3940
#                                                                           ...
# DRILL RIGStation Wagon/Sport Utility Vehicle                                  1
# PKE-SCOOTER                                                                   1
# Station Wagon/Sport Utility VehicleJohn Deere                                 1
# SedanUKN                                                                      1
# MAC TSedan                                                                    1
# Length: 2575, dtype: int64

# %%
df_q =  nyaccidents[nyaccidents["BOROUGH"] == "QUEENS"]

# %%
df_q
# Out:
#        CRASH DATE CRASH TIME BOROUGH  NUMBER OF PERSONS INJURED  \
# 2         4/13/21      17:30  QUEENS                          0
# 10        4/14/21      21:43  QUEENS                          0
# 17        4/15/21      14:30  QUEENS                          0
# 27        4/16/21      11:00  QUEENS                          1
# 28        4/16/21      17:00  QUEENS                          5
# ...           ...        ...     ...                        ...
# 282861     1/1/19      11:00  QUEENS                          0
# 282862     1/1/19      12:30  QUEENS                          0
# 282863     1/1/19       2:18  QUEENS                          0
# 282864     1/1/19      13:00  QUEENS                          0
# 282866     1/1/19      10:23  QUEENS                          1
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 2                              0                              0
# 10                             0                              0
# ...

# %%
df_q
# Out:
#        CRASH DATE CRASH TIME BOROUGH  NUMBER OF PERSONS INJURED  \
# 2         4/13/21      17:30  QUEENS                          0
# 10        4/14/21      21:43  QUEENS                          0
# 17        4/15/21      14:30  QUEENS                          0
# 27        4/16/21      11:00  QUEENS                          1
# 28        4/16/21      17:00  QUEENS                          5
# ...           ...        ...     ...                        ...
# 282861     1/1/19      11:00  QUEENS                          0
# 282862     1/1/19      12:30  QUEENS                          0
# 282863     1/1/19       2:18  QUEENS                          0
# 282864     1/1/19      13:00  QUEENS                          0
# 282866     1/1/19      10:23  QUEENS                          1
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 2                              0                              0
# 10                             0                              0
# ...

# %%
df_q.sum()
# Out:
# /var/folders/25/fh62773n5g987tqzkm3kf5pr0000gn/T/ipykernel_2792/643633864.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_q.sum()
# CRASH DATE                       4/13/214/14/214/15/214/16/214/16/214/16/214/16...
# CRASH TIME                       17:3021:4314:3011:0017:008:058:4013:5513:027:4...
# BOROUGH                          QUEENSQUEENSQUEENSQUEENSQUEENSQUEENSQUEENSQUEE...
# NUMBER OF PERSONS INJURED                                                    26815
# NUMBER OF PERSONS KILLED                                                       120
# NUMBER OF PEDESTRIANS INJURED                                                 4639
# NUMBER OF PEDESTRIANS KILLED                                                    61
# NUMBER OF CYCLIST INJURED                                                     2285
# ...

# %%
#120 people were killed in Queens

# %%
#8 cyclists were killed Queens

# %%
## Filter and subset 
## create a dataset for Manhattan that involved taxi cabs as the primary vehicle cause

# %%
df_m =  nyaccidents[nyaccidents["BOROUGH"] == "MANHATTAN"]

# %%
df_m
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  NUMBER OF PERSONS INJURED  \
# 15        4/16/21      21:20  MANHATTAN                          0
# 16        4/16/21      17:20  MANHATTAN                          0
# 39        4/16/21      20:55  MANHATTAN                          0
# 46        4/15/21      22:25  MANHATTAN                          1
# 47        4/14/21      10:09  MANHATTAN                          0
# ...           ...        ...        ...                        ...
# 282842     1/1/19      20:32  MANHATTAN                          0
# 282847     1/1/19       4:48  MANHATTAN                          0
# 282851     1/1/19       6:00  MANHATTAN                          0
# 282853     1/2/19       9:57  MANHATTAN                          0
# 282872     1/1/19      12:00  MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 15                             0                              0
# ...

# %%
df_taxi1=df_m[df_m["VEHICLE TYPE CODE 1"] == "Taxi"]
df_taxi1
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  NUMBER OF PERSONS INJURED  \
# 67        4/14/21       8:03  MANHATTAN                          1
# 144       4/14/21       0:42  MANHATTAN                          0
# 159       4/16/21      19:54  MANHATTAN                          0
# 283       4/16/21      21:04  MANHATTAN                          0
# 326       4/16/21      16:15  MANHATTAN                          0
# ...           ...        ...        ...                        ...
# 282632     1/1/19       1:30  MANHATTAN                          0
# 282684     1/1/19      16:00  MANHATTAN                          2
# 282802     1/1/19      16:15  MANHATTAN                          0
# 282819     1/1/19      20:30  MANHATTAN                          0
# 282851     1/1/19       6:00  MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 67                             0                              1
# ...

# %%
df_taxi2=df_m[df_m["VEHICLE TYPE CODE 2"] == "Taxi"]
df_taxi2
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  NUMBER OF PERSONS INJURED  \
# 342       4/14/21      16:25  MANHATTAN                          1
# 622       4/17/21      14:11  MANHATTAN                          0
# 1092      4/20/21      16:00  MANHATTAN                          1
# 1450      4/22/21      17:30  MANHATTAN                          1
# 1669      4/23/21      21:10  MANHATTAN                          0
# ...           ...        ...        ...                        ...
# 282453     1/5/19      22:00  MANHATTAN                          3
# 282520     1/3/19       9:55  MANHATTAN                          0
# 282640     1/1/19       4:12  MANHATTAN                          0
# 282685     1/2/19       8:38  MANHATTAN                          0
# 282838     1/1/19       4:00  MANHATTAN                          1
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 342                            0                              0
# ...

# %%
 #I don't see any item in this df called  'primary vehicle cause'

# %%
nyaccidents["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head()
# Out:
# Unspecified                       78494
# Driver Inattention/Distraction    70615
# Failure to Yield Right-of-Way     20691
# Following Too Closely             14407
# Backing Unsafely                  13348
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
## What were the top 5 causes of accidents across all the boroughs?
## by secondary vehicle cause
nyaccidents["CONTRIBUTING FACTOR VEHICLE 2"].value_counts().head()
# Out:
# Unspecified                       190456
# Driver Inattention/Distraction     14186
# Other Vehicular                     3529
# Failure to Yield Right-of-Way       2233
# Passing or Lane Usage Improper      2171
# Name: CONTRIBUTING FACTOR VEHICLE 2, dtype: int64

# %%
## What were the 5 RAREST causes for primary vehicles causing the accident

nyaccidents["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().tail()
# Out:
# Shoulders Defective/Improper    13
# Texting                          8
# Cell Phone (hands-free)          8
# Windshield Inadequate            3
# Listening/Using Headphones       2
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
nyaccidents["CONTRIBUTING FACTOR VEHICLE 1"].unique()
# Out:
# array(['Unspecified', 'Following Too Closely',
#        'Driver Inattention/Distraction', 'Passing Too Closely',
#        'Passing or Lane Usage Improper', 'Driver Inexperience',
#        'Failure to Yield Right-of-Way', 'Turning Improperly',
#        'Unsafe Speed', 'Backing Unsafely', 'Steering Failure',
#        'Traffic Control Disregarded', 'Drugs (illegal)',
#        'Reaction to Uninvolved Vehicle', 'View Obstructed/Limited',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Alcohol Involvement', 'Pavement Slippery', 'Brakes Defective',
#        'Oversized Vehicle', 'Animals Action', 'Unsafe Lane Changing',
#        'Outside Car Distraction', 'Illnes', 'Other Vehicular',
#        'Aggressive Driving/Road Rage', 'Fell Asleep',
#        'Tire Failure/Inadequate', 'Pavement Defective', nan,
#        'Lost Consciousness', 'Accelerator Defective',
#        'Passenger Distraction', 'Glare', 'Eating or Drinking',
# ...

# %%
nyaccidents["CONTRIBUTING FACTOR VEHICLE 2"].unique()
# Out:
# array([nan, 'Unspecified', 'Unsafe Speed',
#        'Driver Inattention/Distraction', 'Failure to Yield Right-of-Way',
#        'Turning Improperly', 'Driver Inexperience',
#        'Following Too Closely', 'View Obstructed/Limited',
#        'Oversized Vehicle', 'Passing Too Closely', 'Other Vehicular',
#        'Traffic Control Disregarded', 'Passing or Lane Usage Improper',
#        'Reaction to Uninvolved Vehicle', 'Backing Unsafely',
#        'Alcohol Involvement', 'Outside Car Distraction',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Obstruction/Debris', 'Aggressive Driving/Road Rage',
#        'Vehicle Vandalism', 'Pavement Slippery', 'Unsafe Lane Changing',
#        'Passenger Distraction', 'Fell Asleep',
#        'Driverless/Runaway Vehicle', 'Drugs (illegal)', 'Fatigued/Drowsy',
#        'Brakes Defective', 'Headlights Defective',
#        'Failure to Keep Right', 'Glare', 'Other Lighting Defects',
# ...

# %%
#animals action, windshield inadequate, and "tow hitch defective" seemed interesting to me!
